# %% [markdown]
# # Doing calculations on timeseries

# %%
import pandas

# %%
df = pandas.read_csv('Messstationen_Tagesdaten_v2_Datensatz_19900101_20250515')
df['time'] = pandas.to_datetime(df['time'])
df = df.set_index('time')
df = df.dropna()
df.head(5)
# Out:
#                            station  cglo_j   rr  tl_mittel  vv_mittel  \
# time
# 2002-01-01 00:00:00+00:00    13305   322.0 -1.0       -4.6        1.5
# 2002-01-02 00:00:00+00:00    13305   566.0  0.0       -3.0        2.1
# 2002-01-03 00:00:00+00:00    13305   684.0 -1.0       -3.7        2.1
# 2002-01-04 00:00:00+00:00    13305   668.0 -1.0      -11.7        1.0
# 2002-01-05 00:00:00+00:00    13305   235.0 -1.0      -12.5        1.0
#
#                            p_mittel  tlmin  tlmax
# time
# 2002-01-01 00:00:00+00:00     972.4   -9.4    0.2
# 2002-01-02 00:00:00+00:00     965.6   -9.8    3.8
# 2002-01-03 00:00:00+00:00     971.8   -7.4    0.1
# 2002-01-04 00:00:00+00:00     975.2  -16.8   -6.6
# 2002-01-05 00:00:00+00:00     975.2  -16.7   -8.2

# %% [markdown]
# ## Works the same as with regular pandas series

# %%
# calculations based on columns
df['tlmax'] - df['tlmin']
# Out:
# time
# 2002-01-01 00:00:00+00:00     9.6
# 2002-01-02 00:00:00+00:00    13.6
# 2002-01-03 00:00:00+00:00     7.5
# 2002-01-04 00:00:00+00:00    10.2
# 2002-01-05 00:00:00+00:00     8.5
#                              ...
# 2018-05-17 00:00:00+00:00     9.7
# 2018-05-18 00:00:00+00:00    11.8
# 2018-05-19 00:00:00+00:00    13.1
# 2018-05-20 00:00:00+00:00    12.9
# 2018-05-21 00:00:00+00:00    11.2
# Length: 5959, dtype: float64

# %%
# calculate the difference between the current and the last timestep
df.diff()
# Out:
#                            station  cglo_j    rr  tl_mittel  vv_mittel  \
# time
# 2002-01-01 00:00:00+00:00      NaN     NaN   NaN        NaN        NaN
# 2002-01-02 00:00:00+00:00      0.0   244.0   1.0        1.6        0.6
# 2002-01-03 00:00:00+00:00      0.0   118.0  -1.0       -0.7        0.0
# 2002-01-04 00:00:00+00:00      0.0   -16.0   0.0       -8.0       -1.1
# 2002-01-05 00:00:00+00:00      0.0  -433.0   0.0       -0.8        0.0
# ...                            ...     ...   ...        ...        ...
# 2018-05-17 00:00:00+00:00      0.0    49.0  -4.2        0.7        0.8
# 2018-05-18 00:00:00+00:00      0.0    67.0   0.0        1.5        0.0
# 2018-05-19 00:00:00+00:00      0.0   620.0   0.0        0.0        1.1
# 2018-05-20 00:00:00+00:00      0.0  -593.0  12.7       -1.1       -1.1
# 2018-05-21 00:00:00+00:00      0.0   289.0 -10.3        1.3        0.0
#
#                            p_mittel  tlmin  tlmax
# time
# 2002-01-01 00:00:00+00:00       NaN    NaN    NaN
# 2002-01-02 00:00:00+00:00      -6.8   -0.4    3.6
# 2002-01-03 00:00:00+00:00       6.2    2.4   -3.7
# 2002-01-04 00:00:00+00:00       3.4   -9.4   -6.7
# 2002-01-05 00:00:00+00:00       0.0    0.1   -1.6
# ...                             ...    ...    ...
# 2018-05-17 00:00:00+00:00       2.6    0.6    0.8
# 2018-05-18 00:00:00+00:00       2.5    0.5    2.6
# 2018-05-19 00:00:00+00:00       1.5   -0.7    0.6
# 2018-05-20 00:00:00+00:00       2.4   -1.0   -1.2
# 2018-05-21 00:00:00+00:00      -3.2    2.2    0.5
#
# [5959 rows x 8 columns]
