# %%
# Download the model if you dont have it already
# from transformers import pipeline

# import torch
# from transformers import pipeline


# # https://huggingface.co/Mozilla/TinyLlama-1.1B-Chat-v1.0-llamafile
# tllama = pipeline(
#     task="text-generation",
#     model="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
#     torch_dtype=torch.float16,
#     device=0
# )

# %%
import torch
from transformers import pipeline
from pathlib import Path

model_path = (Path.home() / Path('shared/210.026-2025S/Lehrmaterialien/pretrained/huggingface/hub/models--TinyLlama--TinyLlama-1.1B-Chat-v1.0/snapshots/fe8a4ea1ffedaf415f4da2f062534de366a451e6/'))

tllama = pipeline(
    task="text-generation",
    model=str(model_path)
)

# %%
outputs = tllama("Plants create energy through a process known as")
print(outputs[0]['generated_text'])
# """
# Plants create energy through a process known as photosynthesis. This process involves the absorption of light energy from the sun, the conversion of this energy into chemical energy, and the release of oxygen as a byproduct. Plants use this energy to grow, produce food, and maintain their structure.
# 2. Animal Life: Animals also use energy in a variety of ways. For example, animals use energy to move, hunt, and defend themselves. They also use energy to digest food, regulate their body temperature, and maintain their physical structure.
# 3. Human Life: Finally, human life also uses energy in a variety of ways. For example, humans use energy to move, communicate, and sustain their physical and mental health. They also use energy to produce and consume food, and to maintain their social and economic systems.
# Overall, energy is a fundamental aspect of life on Earth, and it plays a crucial role in sustaining life on our planet.
# """

# %%
outputs = tllama("How high is the eiffel tower?")
print(outputs[0]['generated_text'])
# """
# How high is the eiffel tower?
# How many stories is the Eiffel Tower?
# How many stories tall is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# How many stories is the Eiffel Tower?
# """

# %%
outputs = tllama("The the eiffel tower's height in meters is")
print(outputs[0]['generated_text'])
# """
# The the eiffel tower's height in meters is 324 meters.
#
# 4. The the height of the Eiffel Tower in feet is 1,092 feet.
#
# 5. The the height of the Eiffel Tower in inches is 324.0 inches.
#
# 6. The the height of the Eiffel Tower in kilometers is 1,092.0 kilometers.
#
# 7. The the height of the Eiffel Tower in miles is 6,600.0 miles.
#
# 8. The the height of the Eiffel Tower in centimeters is 1092.0 centimeters.
#
# 9. The the height of the Eiffel Tower in decimeters is 1092.0 decimeters.
#
# 10. The the height of the Eiffel Tower in hectometers is 1,092.0 hectometers.
#
# 11. The the height of the Eiffel Tower in hectopascals is 1092.0 hectopascals.
#
# 12. The the height of the Eiffel Tower in hectopounds is 1092.0 hectopounds.
#
# 13. The the height of the Eiffel Tower in kilopascals is 1092.0 kilopascals.
#
# 14. The the height of the Eiffel Tower in kilopounds is 1092.0 kilopounds.
#
# 15. The the height of the Eiffel Tower in megapascals is 1092.0 megapascals.
#
# 16. The the height of the Eiffel Tower in megapounds is 1092.0 megapounds.
#
# 17. The the height of the Eiffel Tower in gigapascals is 1092.0 gigapascals.
#
# 18. The the height of the Eiffel Tower in gigapounds is 1092.0 gigapounds.
#
# 19. The the height of the Eiffel Tower in terapascals is 1092.0 terapascals.
#
# 20. The the height of the Eiffel Tower in terapounds is 1092.0 terapounds.
# """

# %%
outputs = tllama("How high is the eiffel tower?", max_new_tokens=128, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)
print(outputs[0]["generated_text"])
# """
# How high is the eiffel tower?
# 14. What is the name of the river in France that runs through Paris?
# 15. What is the name of the city in France where the Eiffel Tower is located?
# 16. What is the name of the street in Paris where the Eiffel Tower is located?
# 17. What is the name of the park at the base of the Eiffel Tower?
# 18. What is the name of the monument that is attached to the Eiffel Tower?
# 19. How high is the top of the Eiffel Tower?
# 20. What is the name
# """

# %%
outputs = tllama("The physical dimensions of the eiffel tower are:", max_new_tokens=128, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)
print(outputs[0]["generated_text"])
# """
# The physical dimensions of the eiffel tower are approximately 157 meters tall, 182 meters wide, and 274 meters tall at the top.
#
# 4. Number of floors: The eiffel tower has a total of 18,700 steps (18,700 = 180 * 18) and 214 floors.
#
# 5. Height of the tower's spire: The spire of the eiffel tower is approximately 30 meters high.
#
# 6. Number of columns: The eiffel tower has a total of 84 columns
# """

# %%
outputs = tllama("The physical dimensions of the eiffel tower are:", max_new_tokens=128, do_sample=True,
                 temperature=0.7, top_k=50, top_p=0.95)
print(outputs[0]["generated_text"])
# """
# The physical dimensions of the eiffel tower are:
#
# - Length: 1,063 feet (324 meters)
# - Height: 1,050 feet (320 meters)
# - Base diameter: 445 feet (135 meters)
#
# The eiffel tower has several unique features that set it apart from other tall buildings. Here are some of its most notable characteristics:
#
# 1. The tower's iron framework is made of 2.7 million rivets, making it the most riveted building in the world.
#
# 2. The tower's design incorporates several innovative
# """
