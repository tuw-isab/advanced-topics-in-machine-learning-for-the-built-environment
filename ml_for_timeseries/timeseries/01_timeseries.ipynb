# %% [markdown]
# # Real world data - TAWES

# %% [markdown]
# ## Tawes weather data example

# %% [markdown]
# Tawes weather data for Vienna city center from 1990 to 2025 is in `Messstationen_Tagesdaten_v2_Datensatz_19900101_20250515.csv`.
# CSV (Comma Separated Value) files can be read with pandas (amongst many other file formats).

# %%
import pandas
df = pandas.read_csv('Messstationen_Tagesdaten_v2_Datensatz_19900101_20250515.csv')
df.head()
# Out:
#                      time  station  tlmax  tlmin  tl_mittel  rf_mittel
# 0  1990-01-01T00:00+00:00     5925   -0.1   -1.6       -0.9        NaN
# 1  1990-01-02T00:00+00:00     5925    1.4   -2.3       -0.5        NaN
# 2  1990-01-03T00:00+00:00     5925    NaN   -0.7        0.4       66.0
# 3  1990-01-04T00:00+00:00     5925    1.2    NaN       -2.2       78.0
# 4  1990-01-05T00:00+00:00     5925   -1.0   -4.6       -2.8       85.0

# %% [markdown]
# tl_mittel is average air temperature, tlmin and tlmax are the respective temperature extrema on these days, rf_mittel is mean relative humidity for this day.
# However, there are no values. NaN is short for Not A Number. And if there is no value in this row (that is otherwise numeric in nature) it simple fills it with this NaN indicator.

# %% [markdown]
# So how to get rid of those NaNs?

# %%
df.dropna().head()
# Out:
#                      time  station  tlmax  tlmin  tl_mittel  rf_mittel
# 4  1990-01-05T00:00+00:00     5925   -1.0   -4.6       -2.8       85.0
# 5  1990-01-06T00:00+00:00     5925   -3.4   -5.7       -4.6       78.0
# 6  1990-01-07T00:00+00:00     5925   -5.2   -8.5       -6.9       90.0
# 7  1990-01-08T00:00+00:00     5925   -5.4   -8.0       -6.7       92.0
# 8  1990-01-09T00:00+00:00     5925   -1.7   -8.7       -5.2       81.0

# %% [markdown]
# This however drops all rows that contain a NaN in any place. clgo was not available until later (2002) so we loose a lot of data. We want to know at least when all temperature values were available)

# %%
df.dropna(subset=['tl_mittel', 'tlmax', 'tlmin']).head()
# Out:
#                      time  station  tlmax  tlmin  tl_mittel  rf_mittel
# 0  1990-01-01T00:00+00:00     5925   -0.1   -1.6       -0.9        NaN
# 1  1990-01-02T00:00+00:00     5925    1.4   -2.3       -0.5        NaN
# 4  1990-01-05T00:00+00:00     5925   -1.0   -4.6       -2.8       85.0
# 5  1990-01-06T00:00+00:00     5925   -3.4   -5.7       -4.6       78.0
# 6  1990-01-07T00:00+00:00     5925   -5.2   -8.5       -6.9       90.0

# %%
df
# Out:
#                          time  station  tlmax  tlmin  tl_mittel  rf_mittel
# 0      1990-01-01T00:00+00:00     5925   -0.1   -1.6       -0.9        NaN
# 1      1990-01-02T00:00+00:00     5925    1.4   -2.3       -0.5        NaN
# 2      1990-01-03T00:00+00:00     5925    NaN   -0.7        0.4       66.0
# 3      1990-01-04T00:00+00:00     5925    1.2    NaN       -2.2       78.0
# 4      1990-01-05T00:00+00:00     5925   -1.0   -4.6       -2.8       85.0
# ...                       ...      ...    ...    ...        ...        ...
# 12914  2025-05-11T00:00+00:00     5925   18.0   10.2       14.1       45.0
# 12915  2025-05-12T00:00+00:00     5925   18.7    9.1       13.9       36.0
# 12916  2025-05-13T00:00+00:00     5925   19.5    9.5       14.5       34.0
# 12917  2025-05-14T00:00+00:00     5925   23.9    8.2       16.1       30.0
# 12918  2025-05-15T00:00+00:00     5925    NaN    NaN        NaN        NaN
#
# [12919 rows x 6 columns]

# %% [markdown]
# ## Accessing columns

# %% [markdown]
# One can access separate columns (can be multiple) like we would with a dictionary:

# %%
df['tl_mittel']
# Out:
# 0        -0.9
# 1        -0.5
# 2         0.4
# 3        -2.2
# 4        -2.8
#          ...
# 12914    14.1
# 12915    13.9
# 12916    14.5
# 12917    16.1
# 12918     NaN
# Name: tl_mittel, Length: 12919, dtype: float64

# %%
df[['tl_mittel', 'tlmin', 'tlmax']]
# Out:
#        tl_mittel  tlmin  tlmax
# 0           -0.9   -1.6   -0.1
# 1           -0.5   -2.3    1.4
# 2            0.4   -0.7    NaN
# 3           -2.2    NaN    1.2
# 4           -2.8   -4.6   -1.0
# ...          ...    ...    ...
# 12914       14.1   10.2   18.0
# 12915       13.9    9.1   18.7
# 12916       14.5    9.5   19.5
# 12917       16.1    8.2   23.9
# 12918        NaN    NaN    NaN
#
# [12919 rows x 3 columns]

# %% [markdown]
# ## Basic maths operations

# %% [markdown]
# Lets do some basic operations. Make a new column with the temperature differential tlmax - tmin.

# %%
df['tl_diff'] = df['tlmax'] - df['tlmin']
df.head()
# Out:
#                      time  station  tlmax  tlmin  tl_mittel  rf_mittel  \
# 0  1990-01-01T00:00+00:00     5925   -0.1   -1.6       -0.9        NaN
# 1  1990-01-02T00:00+00:00     5925    1.4   -2.3       -0.5        NaN
# 2  1990-01-03T00:00+00:00     5925    NaN   -0.7        0.4       66.0
# 3  1990-01-04T00:00+00:00     5925    1.2    NaN       -2.2       78.0
# 4  1990-01-05T00:00+00:00     5925   -1.0   -4.6       -2.8       85.0
#
#    tl_diff
# 0      1.5
# 1      3.7
# 2      NaN
# 3      NaN
# 4      3.6

# %% [markdown]
# **Exercise**: Create a new column named 'freezing' that contains True if the min temparature was below 0 and False otherwise.

# %% [markdown]
# **Exercise**: Instead of True and False this freezing column should contain 1 and 0 (1 if True, 0 if False)

# %% [markdown]
# ## Basic stats

# %% [markdown]
# Get some basic statistics on the data using describe().

# %%
df.describe()
# Out:
#        station         tlmax         tlmin     tl_mittel     rf_mittel  \
# count  12919.0  12917.000000  12917.000000  12918.000000  12916.000000
# mean    5925.0     16.314973      9.104529     12.730276     67.103825
# std        0.0      9.588808      7.411942      8.402692     14.342467
# min     5925.0    -10.000000    -15.400000    -12.700000     19.000000
# 25%     5925.0      8.600000      3.200000      6.000000     57.000000
# 50%     5925.0     16.500000      9.300000     13.000000     67.000000
# 75%     5925.0     24.100000     15.200000     19.600000     78.000000
# max     5925.0     39.500000     26.900000     32.300000    100.000000
#
#             tl_diff
# count  12916.000000
# mean       7.210855
# std        3.437491
# min        0.500000
# 25%        4.400000
# 50%        6.900000
# 75%        9.700000
# max       18.500000

# %% [markdown]
# ## Conditional slicing, finding and counting occurrences

# %% [markdown]
# When was the coldest day in Vienna? We can see above that tlmin had a lowest value of -15.4, but when?
# We can use conditions that evaluate to true or false (like the freezing one above) as indexers.

# %%
df['tlmin'] == -15.4
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12914    False
# 12915    False
# 12916    False
# 12917    False
# 12918    False
# Name: tlmin, Length: 12919, dtype: bool

# %%
df[df['tlmin'] == -15.4]
# Out:
#                         time  station  tlmax  tlmin  tl_mittel  rf_mittel  \
# 2553  1996-12-28T00:00+00:00     5925  -10.0  -15.4      -12.7       66.0
#
#       tl_diff
# 2553      5.4

# %% [markdown]
# We can use this to select whole ranges of data where some condition applies. E.g. select all data where it was freezing.

# %%
df['freezing'] = (df['tlmin'] < 0).astype(int)
df[df['freezing'] == 1]
# Out:
#                          time  station  tlmax  tlmin  tl_mittel  rf_mittel  \
# 0      1990-01-01T00:00+00:00     5925   -0.1   -1.6       -0.9        NaN
# 1      1990-01-02T00:00+00:00     5925    1.4   -2.3       -0.5        NaN
# 2      1990-01-03T00:00+00:00     5925    NaN   -0.7        0.4       66.0
# 4      1990-01-05T00:00+00:00     5925   -1.0   -4.6       -2.8       85.0
# 5      1990-01-06T00:00+00:00     5925   -3.4   -5.7       -4.6       78.0
# ...                       ...      ...    ...    ...        ...        ...
# 12835  2025-02-21T00:00+00:00     5925    4.5   -0.9        1.8       46.0
# 12836  2025-02-22T00:00+00:00     5925    7.8   -0.8        3.5       46.0
# 12837  2025-02-23T00:00+00:00     5925    4.6   -0.6        2.0       64.0
# 12860  2025-03-18T00:00+00:00     5925    6.4   -0.4        3.0       42.0
# 12861  2025-03-19T00:00+00:00     5925   11.2   -0.4        5.4       42.0
#
#        tl_diff  freezing
# 0          1.5         1
# 1          3.7         1
# 2          NaN         1
# 4          3.6         1
# 5          2.3         1
# ...        ...       ...
# 12835      5.4         1
# 12836      8.6         1
# 12837      5.2         1
# 12860      6.8         1
# 12861     11.6         1
#
# [1486 rows x 8 columns]

# %% [markdown]
# We can use value_counts to see what value occurs how often in the dataframe.

# %%
df['freezing'].value_counts()
# Out:
# freezing
# 0    11433
# 1     1486
# Name: count, dtype: int64

# %% [markdown]
# **Exercise**: How many days were the temperature was always freezing (look at tlmax) and what percentage of the time does this represent.

# %% [markdown]
# ## Time indexed DataFrames

# %% [markdown]
# Pandas supports datetime indices

# %%
df['time'] = pandas.to_datetime(df['time'], utc=True)
df = df.set_index('time', drop=True)

# %%
df.head()
# Out:
#                            station  tlmax  tlmin  tl_mittel  rf_mittel  \
# time
# 1990-01-01 00:00:00+00:00     5925   -0.1   -1.6       -0.9        NaN
# 1990-01-02 00:00:00+00:00     5925    1.4   -2.3       -0.5        NaN
# 1990-01-03 00:00:00+00:00     5925    NaN   -0.7        0.4       66.0
# 1990-01-04 00:00:00+00:00     5925    1.2    NaN       -2.2       78.0
# 1990-01-05 00:00:00+00:00     5925   -1.0   -4.6       -2.8       85.0
#
#                            tl_diff  freezing
# time
# 1990-01-01 00:00:00+00:00      1.5         1
# 1990-01-02 00:00:00+00:00      3.7         1
# 1990-01-03 00:00:00+00:00      NaN         1
# 1990-01-04 00:00:00+00:00      NaN         0
# 1990-01-05 00:00:00+00:00      3.6         1

# %% [markdown]
# Now we can index rows based on times.

# %%
df['2011-03-01 00:00': '2011-03-02 00:00']
# Out:
#                            station  tlmax  tlmin  tl_mittel  rf_mittel  \
# time
# 2011-03-01 00:00:00+00:00     5925    5.2   -0.8        2.2       71.0
# 2011-03-02 00:00:00+00:00     5925    4.3   -2.3        1.0       56.0
#
#                            tl_diff  freezing
# time
# 2011-03-01 00:00:00+00:00      6.0         1
# 2011-03-02 00:00:00+00:00      6.6         1

# %% [markdown]
# We can now resample the dataframe to some other resolution. Resampling to a lower frequency is called downsampling, to a higher frequency this is called upsampling.
#
# When resampling, one has to specify a frequency and a method.
#
# For example yearly avarages:

# %%
df.resample('1YS').mean()
# Out:
#                            station      tlmax      tlmin  tl_mittel  \
# time
# 1990-01-01 00:00:00+00:00   5925.0  16.130769   8.649725  12.371781
# 1991-01-01 00:00:00+00:00   5925.0  14.657260   7.773425  11.234247
# 1992-01-01 00:00:00+00:00   5925.0  16.285246   9.139891  12.737978
# 1993-01-01 00:00:00+00:00   5925.0  15.391233   8.088767  11.758630
# 1994-01-01 00:00:00+00:00   5925.0  16.803836   9.529863  13.190959
# 1995-01-01 00:00:00+00:00   5925.0  15.191233   8.569863  11.899178
# 1996-01-01 00:00:00+00:00   5925.0  13.544262   7.230874  10.403825
# 1997-01-01 00:00:00+00:00   5925.0  15.089863   8.157260  11.643562
# 1998-01-01 00:00:00+00:00   5925.0  15.849315   8.727397  12.309589
# 1999-01-01 00:00:00+00:00   5925.0  15.664110   8.950685  12.332055
# 2000-01-01 00:00:00+00:00   5925.0  17.090710   9.526503  13.329235
# 2001-01-01 00:00:00+00:00   5925.0  15.658904   8.635890  12.168767
# 2002-01-01 00:00:00+00:00   5925.0  16.550411   9.356438  12.974795
# 2003-01-01 00:00:00+00:00   5925.0  16.411781   8.765205  12.605479
# 2004-01-01 00:00:00+00:00   5925.0  15.377322   8.572404  11.997268
# 2005-01-01 00:00:00+00:00   5925.0  15.369315   8.381096  11.896712
# 2006-01-01 00:00:00+00:00   5925.0  15.956438   8.898630  12.448767
# 2007-01-01 00:00:00+00:00   5925.0  17.019178   9.624110  13.342192
# 2008-01-01 00:00:00+00:00   5925.0  16.639344   9.528689  13.109016
# 2009-01-01 00:00:00+00:00   5925.0  16.321644   9.218904  12.789041
# 2010-01-01 00:00:00+00:00   5925.0  14.827397   8.286849  11.573425
# 2011-01-01 00:00:00+00:00   5925.0  16.558356   9.014795  12.809041
# 2012-01-01 00:00:00+00:00   5925.0  16.870765   9.137432  13.025137
# 2013-01-01 00:00:00+00:00   5925.0  15.741644   9.090137  12.436712
# 2014-01-01 00:00:00+00:00   5925.0  17.013151  10.167123  13.611781
# 2015-01-01 00:00:00+00:00   5925.0  17.424110   9.914521  13.695342
# 2016-01-01 00:00:00+00:00   5925.0  16.735246   9.447814  13.113115
# 2017-01-01 00:00:00+00:00   5925.0  16.923288   9.409041  13.188767
# 2018-01-01 00:00:00+00:00   5925.0  17.668219  10.332603  14.023014
# 2019-01-01 00:00:00+00:00   5925.0  17.829589  10.176438  14.025753
# 2020-01-01 00:00:00+00:00   5925.0  17.275137   9.589617  13.457650
# 2021-01-01 00:00:00+00:00   5925.0  16.436986   8.935342  12.709863
# 2022-01-01 00:00:00+00:00   5925.0  17.585205  10.021370  13.828767
# 2023-01-01 00:00:00+00:00   5925.0  18.043836  10.401096  14.247397
# 2024-01-01 00:00:00+00:00   5925.0  18.587705  10.944262  14.788798
# 2025-01-01 00:00:00+00:00   5925.0  12.219403   4.909701   8.585075
#
#                            rf_mittel   tl_diff  freezing
# time
# 1990-01-01 00:00:00+00:00  68.749311  7.496419  0.082192
# 1991-01-01 00:00:00+00:00  71.876712  6.883836  0.156164
# 1992-01-01 00:00:00+00:00  68.994536  7.145355  0.076503
# 1993-01-01 00:00:00+00:00  71.391781  7.302466  0.186301
# 1994-01-01 00:00:00+00:00  68.819178  7.273973  0.079452
# 1995-01-01 00:00:00+00:00  69.772603  6.621370  0.134247
# 1996-01-01 00:00:00+00:00  72.661202  6.313388  0.210383
# 1997-01-01 00:00:00+00:00  70.273973  6.932603  0.128767
# 1998-01-01 00:00:00+00:00  69.282192  7.121918  0.161644
# 1999-01-01 00:00:00+00:00  73.534247  6.713425  0.123288
# 2000-01-01 00:00:00+00:00  67.795082  7.564208  0.079235
# 2001-01-01 00:00:00+00:00  66.879452  7.023014  0.136986
# 2002-01-01 00:00:00+00:00  70.673973  7.193973  0.104110
# 2003-01-01 00:00:00+00:00  66.923288  7.646575  0.175342
# 2004-01-01 00:00:00+00:00  68.601093  6.804918  0.158470
# 2005-01-01 00:00:00+00:00  69.526027  6.988219  0.158904
# 2006-01-01 00:00:00+00:00  69.635616  7.057808  0.172603
# 2007-01-01 00:00:00+00:00  68.010959  7.395068  0.073973
# 2008-01-01 00:00:00+00:00  69.926230  7.110656  0.065574
# 2009-01-01 00:00:00+00:00  69.734247  7.102740  0.115068
# 2010-01-01 00:00:00+00:00  68.336986  6.540548  0.194521
# 2011-01-01 00:00:00+00:00  69.471233  7.543562  0.134247
# 2012-01-01 00:00:00+00:00  69.573770  7.733333  0.103825
# 2013-01-01 00:00:00+00:00  69.671233  6.651507  0.123288
# 2014-01-01 00:00:00+00:00  66.835616  6.846027  0.057534
# 2015-01-01 00:00:00+00:00  62.589041  7.509589  0.054795
# 2016-01-01 00:00:00+00:00  63.193989  7.287432  0.092896
# 2017-01-01 00:00:00+00:00  59.761644  7.514247  0.112329
# 2018-01-01 00:00:00+00:00  60.684932  7.335616  0.123288
# 2019-01-01 00:00:00+00:00  60.191781  7.653151  0.082192
# 2020-01-01 00:00:00+00:00  60.882514  7.685519  0.081967
# 2021-01-01 00:00:00+00:00  61.764384  7.501644  0.093151
# 2022-01-01 00:00:00+00:00  60.504110  7.563836  0.071233
# 2023-01-01 00:00:00+00:00  62.857534  7.642740  0.054795
# 2024-01-01 00:00:00+00:00  62.486339  7.643443  0.040984
# 2025-01-01 00:00:00+00:00  58.320896  7.309701  0.185185

# %% [markdown]
# We can also resample to a higher frequency than the original data.
#
# For example upsampling to hourly frequency while using linear interpolation.

# %%
small_df = df['2011-03-01 00:00': '2011-03-07 00:00'].copy() 
small_df.resample('1h').interpolate()
# Out:
#                            station     tlmax     tlmin  tl_mittel  rf_mittel  \
# time
# 2011-03-01 00:00:00+00:00   5925.0  5.200000 -0.800000     2.2000  71.000000
# 2011-03-01 01:00:00+00:00   5925.0  5.162500 -0.862500     2.1500  70.375000
# 2011-03-01 02:00:00+00:00   5925.0  5.125000 -0.925000     2.1000  69.750000
# 2011-03-01 03:00:00+00:00   5925.0  5.087500 -0.987500     2.0500  69.125000
# 2011-03-01 04:00:00+00:00   5925.0  5.050000 -1.050000     2.0000  68.500000
# ...                            ...       ...       ...        ...        ...
# 2011-03-06 20:00:00+00:00   5925.0  4.533333 -0.533333     2.0500  44.666667
# 2011-03-06 21:00:00+00:00   5925.0  4.450000 -0.675000     1.9375  44.500000
# 2011-03-06 22:00:00+00:00   5925.0  4.366667 -0.816667     1.8250  44.333333
# 2011-03-06 23:00:00+00:00   5925.0  4.283333 -0.958333     1.7125  44.166667
# 2011-03-07 00:00:00+00:00   5925.0  4.200000 -1.100000     1.6000  44.000000
#
#                             tl_diff  freezing
# time
# 2011-03-01 00:00:00+00:00  6.000000  1.000000
# 2011-03-01 01:00:00+00:00  6.025000  1.000000
# 2011-03-01 02:00:00+00:00  6.050000  1.000000
# 2011-03-01 03:00:00+00:00  6.075000  1.000000
# 2011-03-01 04:00:00+00:00  6.100000  1.000000
# ...                             ...       ...
# 2011-03-06 20:00:00+00:00  5.066667  0.833333
# 2011-03-06 21:00:00+00:00  5.125000  0.875000
# 2011-03-06 22:00:00+00:00  5.183333  0.916667
# 2011-03-06 23:00:00+00:00  5.241667  0.958333
# 2011-03-07 00:00:00+00:00  5.300000  1.000000
#
# [145 rows x 7 columns]

# %% [markdown]
# **Exercise**: Resample the 'freezing' column to yearly frequency providing not the mean (as in the examples above) but the sum within each year.
